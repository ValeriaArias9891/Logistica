# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Age','Survived']].head()
# Out:
#     Age  Survived
# 0  22.0         0
# 1  38.0         1
# 2  26.0         1
# 3  35.0         1
# 4  35.0         0

# %%
df[['Survived','Age']].plot.scatter(x='Age',y='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Survived'>

# %%
w= 0.09
b= -3.6


x= np.linspace(0, df['Age'].max(), 100)
y= 1/(1+np.exp(-(w*x+b)))

# %%
df.plot.scatter(x='Age',y='Survived')
plt.plot(x,y, color='black')
plt.ylim(0,df['Survived'].max()*1.1)
plt.scatter(x,y, color='pink')

plt.xlabel('Age')
plt.ylabel('Supervivencia 1: positivo, 0: negativo')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
